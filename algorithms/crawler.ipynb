# %%
# Retrieve all categories using namespace=14
import requests
import json
subcategory_url = 'https://en.wikipedia.org/w/api.php?action=query&format=json&list=categorymembers&cmnamespace=14&cmlimit=500&cmtitle=Category:Algorithms'
r = requests.get(subcategory_url)
subcategories = json.loads(r.text)
# print(subcategories)
categorymembers = subcategories['query']['categorymembers']
print(categorymembers)
# Out:
# [{'ns': 14, 'title': 'Category:Computer algebra', 'pageid': 984658}, {'ns': 14, 'title': 'Category:Algorithm description languages', 'pageid': 28871963}, {'ns': 14, 'title': 'Category:Algorithmic trading', 'pageid': 50947841}, {'ns': 14, 'title': 'Category:Approximation algorithms', 'pageid': 2597177}, {'ns': 14, 'title': 'Category:Bioinformatics algorithms', 'pageid': 16659854}, {'ns': 14, 'title': 'Category:Calendar algorithms', 'pageid': 16660451}, {'ns': 14, 'title': 'Category:Checksum algorithms', 'pageid': 1063613}, {'ns': 14, 'title': 'Category:Combinatorial algorithms', 'pageid': 2634128}, {'ns': 14, 'title': 'Category:Compression algorithms', 'pageid': 702589}, {'ns': 14, 'title': 'Category:Computer arithmetic algorithms', 'pageid': 38133621}, {'ns': 14, 'title': 'Category:Concurrent algorithms', 'pageid': 15913343}, {'ns': 14, 'title': 'Category:Cryptographic algorithms', 'pageid': 704483}, {'ns': 14, 'title': 'Category:Data mining algorithms', 'pageid': 46456200}, {'ns': 14, 'title': 'Category:Database algorithms', 'pageid': 16654862}, {'ns': 14, 'title': 'Category:Digit-by-digit algorithms', 'pageid': 49025414}, {'ns': 14, 'title': 'Category:Digital signal processing', 'pageid': 707453}, {'ns': 14, 'title': 'Category:Distributed algorithms', 'pageid': 15970362}, {'ns': 14, 'title': 'Category:Error detection and correction', 'pageid': 1061200}, {'ns': 14, 'title': 'Category:Evolutionary algorithms', 'pageid': 754055}, {'ns': 14, 'title': 'Category:External memory algorithms', 'pageid': 21813091}, {'ns': 14, 'title': 'Category:Fair division protocols', 'pageid': 44514892}, {'ns': 14, 'title': 'Category:Fingerprinting algorithms', 'pageid': 50017828}, {'ns': 14, 'title': 'Category:Graph algorithms', 'pageid': 699287}, {'ns': 14, 'title': 'Category:Computational group theory', 'pageid': 1426374}, {'ns': 14, 'title': 'Category:Heuristic algorithms', 'pageid': 23173987}, {'ns': 14, 'title': 'Category:Machine learning algorithms', 'pageid': 33547228}, {'ns': 14, 'title': 'Category:Matrix multiplication algorithms', 'pageid': 45081487}, {'ns': 14, 'title': 'Category:Memory management algorithms', 'pageid': 16143225}, {'ns': 14, 'title': 'Category:Networking algorithms', 'pageid': 12026628}, {'ns': 14, 'title': 'Category:Computational number theory', 'pageid': 1183044}, {'ns': 14, 'title': 'Category:Numerical analysis', 'pageid': 697506}, {'ns': 14, 'title': 'Category:Online algorithms', 'pageid': 16661272}, {'ns': 14, 'title': 'Category:Optimization algorithms and methods', 'pageid': 34044100}, {'ns': 14, 'title': 'Category:Pattern matching', 'pageid': 2023695}, {'ns': 14, 'title': 'Category:Computational physics', 'pageid': 792595}, {'ns': 14, 'title': 'Category:Pseudo-polynomial time algorithms', 'pageid': 31209842}, {'ns': 14, 'title': 'Category:Pseudorandom number generators', 'pageid': 1060172}, {'ns': 14, 'title': 'Category:Quantum algorithms', 'pageid': 702600}, {'ns': 14, 'title': 'Category:Randomized algorithms', 'pageid': 31548188}, {'ns': 14, 'title': 'Category:Recursion', 'pageid': 22601667}, {'ns': 14, 'title': 'Category:Root-finding algorithms', 'pageid': 697463}, {'ns': 14, 'title': 'Category:Routing algorithms', 'pageid': 1882018}, {'ns': 14, 'title': 'Category:Scheduling algorithms', 'pageid': 1690419}, {'ns': 14, 'title': 'Category:Search algorithms', 'pageid': 1406201}, {'ns': 14, 'title': 'Category:Selection algorithms', 'pageid': 2597043}, {'ns': 14, 'title': 'Category:Signal processing', 'pageid': 763505}, {'ns': 14, 'title': 'Category:Sorting algorithms', 'pageid': 11604026}, {'ns': 14, 'title': 'Category:Statistical algorithms', 'pageid': 6536797}, {'ns': 14, 'title': 'Category:Computational statistics', 'pageid': 9272793}, {'ns': 14, 'title': 'Category:Stochastic algorithms', 'pageid': 25478219}, {'ns': 14, 'title': 'Category:Algorithms on strings', 'pageid': 704505}, {'ns': 14, 'title': 'Category:Unicode algorithms', 'pageid': 11068908}]

# %%
# Create links to follow to retrieve all algorithms within each category using namespace=0
seed_url = 'https://en.wikipedia.org/w/api.php?action=query&format=json&list=categorymembers&cmnamespace=0&cmlimit=500&cmtitle='
categories = []
def build_url(catmems):
    for catmem in catmems:
        page = {}
        page['Category'] = catmem['title'][9:]
        url = seed_url + catmem['title']
        page['URL'] = url
        categories.append(page)
        
build_url(categorymembers)
# print(categories)

# %%
# Downloading the entire web content
def download_page(url):
    try:
        req = requests.get(url)
        respData = json.loads(req.text)
        return respData['query']['categorymembers']
    except Exception as e:
        print(str(e))

# Get all algorithms for each category
def get_algorithms(categories):
    count = 0
    for category in categories:
        respData = download_page(category['URL'])
        category['Algorithms'] = respData
        count += len(respData)
    return count
number_of_algorithms = get_algorithms(categories)
print(number_of_algorithms, categories)
# Out:
# 2202 [{'URL': 'https://en.wikipedia.org/w/api.php?action=query&format=json&list=categorymembers&cmnamespace=0&cmlimit=500&cmtitle=Category:Computer algebra', 'Algorithms': [{'ns': 0, 'title': 'Automatic differentiation', 'pageid': 734787}, {'ns': 0, 'title': 'Bareiss algorithm', 'pageid': 17919686}, {'ns': 0, 'title': 'Berlekamp–Zassenhaus algorithm', 'pageid': 25744542}, {'ns': 0, 'title': "Berlekamp's algorithm", 'pageid': 6057100}, {'ns': 0, 'title': "Buchberger's algorithm", 'pageid': 696317}, {'ns': 0, 'title': 'Cantor–Zassenhaus algorithm', 'pageid': 6059689}, {'ns': 0, 'title': 'Conway polynomial (finite fields)', 'pageid': 30798197}, {'ns': 0, 'title': 'Dimension of an algebraic variety', 'pageid': 253251}, {'ns': 0, 'title': 'Elementary function', 'pageid': 10412}, {'ns': 0, 'title': 'Elimination theory', 'pageid': 245978}, {'ns': 0, 'title': 'Factorization of polynomials', 'pageid': 3776351}, {'ns': 0, 'title': 'Factorization of polynomials over finite fields', 'pageid': 30059275}, {'ns': 0, 'title': "Faugère's F4 and F5 algorithms", 'pageid': 6212640}, {'ns': 0, 'title': 'FGLM algorithm', 'pageid': 53596792}, {'ns': 0, 'title': "Gosper's algorithm", 'pageid': 19590493}, {'ns': 0, 'title': 'Gröbner basis', 'pageid': 357328}, {'ns': 0, 'title': 'Gröbner fan', 'pageid': 53625492}, {'ns': 0, 'title': 'International Symposium on Symbolic and Algebraic Computation', 'pageid': 39273382}, {'ns': 0, 'title': 'Janet basis', 'pageid': 41553887}, {'ns': 0, 'title': 'Journal of Symbolic Computation', 'pageid': 6528528}, {'ns': 0, 'title': 'Kronecker substitution', 'pageid': 24439531}, {'ns': 0, 'title': "Landau's algorithm", 'pageid': 24610350}, {'ns': 0, 'title': 'Liouvillian function', 'pageid': 47147130}, {'ns': 0, 'title': 'Ore algebra', 'pageid': 44311819}, {'ns': 0, 'title': "Pollard's kangaroo algorithm", 'pageid': 12928899}, {'ns': 0, 'title': 'Polynomial decomposition', 'pageid': 47164545}, {'ns': 0, 'title': 'Polynomial greatest common divisor', 'pageid': 9927028}, {'ns': 0, 'title': 'Polynomial identity testing', 'pageid': 20593462}, {'ns': 0, 'title': 'Polynomial long division', 'pageid': 314205}, {'ns': 0, 'title': 'Regular chain', 'pageid': 18814716}, {'ns': 0, 'title': 'Regular semi-algebraic system', 'pageid': 29317092}, {'ns': 0, 'title': 'RegularChains', 'pageid': 29309766}, {'ns': 0, 'title': 'Resultant', 'pageid': 2195020}, {'ns': 0, 'title': 'Risch algorithm', 'pageid': 289450}, {'ns': 0, 'title': 'Schwartz–Zippel lemma', 'pageid': 2789076}, {'ns': 0, 'title': 'Square-free polynomial', 'pageid': 3816655}, {'ns': 0, 'title': "Sturm's theorem", 'pageid': 1221919}, {'ns': 0, 'title': 'Sum of radicals', 'pageid': 22231261}, {'ns': 0, 'title': 'Symbolic computation', 'pageid': 23659805}, {'ns': 0, 'title': 'Symbolic integration', 'pageid': 1652672}, {'ns': 0, 'title': 'Symbolic regression', 'pageid': 42922637}, {'ns': 0, 'title': 'Symbolic-numeric computation', 'pageid': 22288224}, {'ns': 0, 'title': 'Synthetic division', 'pageid': 314709}, {'ns': 0, 'title': 'System of polynomial equations', 'pageid': 27420015}, {'ns': 0, 'title': 'Teo Mora', 'pageid': 53596978}, {'ns': 0, 'title': 'Triangular decomposition', 'pageid': 29321051}, {'ns': 0, 'title': "Wu's method of characteristic set", 'pageid': 13284111}], 'Category': 'Computer algebra'}, {'URL': 'https://en.wikipedia.org/w/api.php?action=query&format=json&list=categorymembers&cmnamespace=0&cmlimit=500&cmtitle=Category:Algorithm description languages', 'Algorithms': [{'ns': 0, 'title': 'Flowchart', 'pageid': 527453}, {'ns': 0, 'title': 'Natural language programming', 'pageid': 18784729}, {'ns': 0, 'title': 'Pidgin code', 'pageid': 958409}, {'ns': 0, 'title': 'PlusCal', 'pageid': 28752783}, {'ns': 0, 'title': 'Program Design Language', 'pageid': 2641112}, {'ns': 0, 'title': 'Pseudocode', 'pageid': 24185}, {'ns': 0, 'title': 'Structured English', 'pageid': 11643262}], 'Category': 'Algorithm description languages'}, {'URL': 'https://en.wikipedia.org/w/api.php?actio ...

# %%
# Create abbreviations for algorithms with leading letters
def create_abbreviations(line):
    if len(line.split()) >= 2:
        return ''.join(w[0].upper() for w in line.split())

# Remove text within brackets and add abbreviation for each algorithm
import re
def remove_brackets_and_add_abbre(categories):
    for category in categories:
        for algorithm in category['Algorithms']:
            if algorithm['title'][-1] == ")":
                algorithm['title'] = re.sub("[\(\[].*?[\)\]]", "", algorithm['title'])
            algorithm['abbreviation'] = create_abbreviations(algorithm['title'])
          
remove_brackets_and_add_abbre(categories)

# %%
# Write the final result to a json file
result = {}
result['categories'] = categories
with open('categories.json', 'w') as outfile:
    json.dump(result, outfile)
